# %% [markdown]
# <a href="https://colab.research.google.com/github/satyhim/Project-2-Bangalore_Cafe/blob/main/Rough5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %%
#At first we need to import the received data as :
df=pd.read_csv('/content/drive/MyDrive/Python/Project/Bangalore_Cafe_Zomato.csv')
df
# Out:
#                                                    name online_order  \
# 0                                       San Churro Cafe          Yes
# 1                                        Penthouse Cafe          Yes
# 2                                             Smacznego          Yes
# 3     CafÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂ© Down The A...          Yes
# 4                                          Cafe Shuffle          Yes
# ...                                                 ...          ...
# 4372                                           Tata Cha          Yes
# 4373                                            Teashot           No
# 4374                         The Coffee Bean & Tea Leaf          Yes
# 4375                                         Cafe Thulp          Yes
# 4376      Re:fuel- Aloft Bengaluru Cessna Business Park           No
#
#      book_table    rate  votes                    location  \
# 0            No   3.8/5    918                Banashankari
# 1            No   4.0/5    324                Banashankari
# 2            No   4.2/5    504                Banashankari
# 3            No   4.1/5    402                Banashankari
# 4           Yes   4.2/5    150                Banashankari
# ...         ...     ...    ...                         ...
# 4372         No     NEW      0                  Whitefield
# 4373         No  2.9 /5     24                  Whitefield
# 4374         No  3.0 /5     38                  Whitefield
# 4375         No  3.6 /5     57  ITPL Main Road, Whitefield
# 4376         No     NaN      0                   Bellandur
#
#                 rest_type                                         dish_liked  \
# 0     Cafe, Casual Dining  Churros, Cannelloni, Minestrone Soup, Hot Choc...
# 1                    Cafe  Pizza, Mocktails, Coffee, Nachos, Salad, Pasta...
# 2                    Cafe  Waffles, Pasta, Coleslaw Sandwich, Choco Waffl...
# 3                    Cafe  Waffles, Pasta, Crispy Chicken, Honey Chilli C...
# 4                    Cafe  Mocktails, Peri Fries, Lasagne, Pizza, Chicken...
# ...                   ...                                                ...
# 4372                 Cafe                                                NaN
# 4373                 Cafe                                                NaN
# 4374                 Cafe                                                NaN
# 4375                 Cafe  Burgers, Pasta Alfredo, Pulled Pork Burger, Pizza
# 4376         Cafe, Bakery                                                NaN
#
#                                                cuisines  \
# 0                                Cafe, Mexican, Italian
# 1                            Cafe, Italian, Continental
# 2              Cafe, Mexican, Italian, Momos, Beverages
# 3                                                  Cafe
# 4                            Cafe, Italian, Continental
# ...                                                 ...
# 4372                            Cafe, Tea, North Indian
# 4373                                               Cafe
# 4374                                       Cafe, Coffee
# 4375                       Cafe, Burger, Italian, Salad
# 4376  Bakery, Beverages, Cafe, Coffee, Desserts, San...
#
#      approx_cost(for two people) listed_in(type) listed_in(city)
# 0                            800          Buffet    Banashankari
# 1                            700             NaN             NaN
# 2                            550           Cafes    Banashankari
# 3                            500           Cafes    Banashankari
# 4                            600           Cafes    Banashankari
# ...                          ...             ...             ...
# 4372                         500        Dine-out      Whitefield
# 4373                         150        Dine-out      Whitefield
# 4374                         700        Dine-out      Whitefield
# 4375                       1,000        Dine-out      Whitefield
# 4376                       1,000        Dine-out      Whitefield
#
# [4377 rows x 12 columns]

# %% [markdown]
# #Data Desicription:
#
# As we can see in received data we have
#
# *   Reows = 4377
# *   Column = 12
#
# Column Names :

# %%
for col in df:
    print(col)
# Out:
# name
# online_order
# book_table
# rate
# votes
# location
# rest_type
# dish_liked
# cuisines
# approx_cost(for two people)
# listed_in(type)
# listed_in(city)

# %%
df.describe()
# Out:
#               votes
# count   4377.000000
# mean     436.056203
# std     1100.397778
# min        0.000000
# 25%       24.000000
# 50%       99.000000
# 75%      450.000000
# max    14726.000000

# %% [markdown]
# We can see sequence of column names is not proper so i am rearrenging the column names to have better understanding of the data:
#
# To change column  names we can use :

# %%
df.head(2)
# Out:
#               name online_order book_table   rate  votes      location  \
# 0  San Churro Cafe          Yes         No  3.8/5    918  Banashankari
# 1   Penthouse Cafe          Yes         No  4.0/5    324  Banashankari
#
#              rest_type                                         dish_liked  \
# 0  Cafe, Casual Dining  Churros, Cannelloni, Minestrone Soup, Hot Choc...
# 1                 Cafe  Pizza, Mocktails, Coffee, Nachos, Salad, Pasta...
#
#                      cuisines approx_cost(for two people) listed_in(type)  \
# 0      Cafe, Mexican, Italian                         800          Buffet
# 1  Cafe, Italian, Continental                         700             NaN
#
#   listed_in(city)
# 0    Banashankari
# 1             NaN

# %%
df = df[['name', 'listed_in(city)', 'rest_type', 'dish_liked','cuisines','location','approx_cost(for two people)','online_order','book_table','rate','votes','listed_in(type)']]

# %%
df.head(2)
# Out:
#               name listed_in(city)            rest_type  \
# 0  San Churro Cafe    Banashankari  Cafe, Casual Dining
# 1   Penthouse Cafe             NaN                 Cafe
#
#                                           dish_liked  \
# 0  Churros, Cannelloni, Minestrone Soup, Hot Choc...
# 1  Pizza, Mocktails, Coffee, Nachos, Salad, Pasta...
#
#                      cuisines      location approx_cost(for two people)  \
# 0      Cafe, Mexican, Italian  Banashankari                         800
# 1  Cafe, Italian, Continental  Banashankari                         700
#
#   online_order book_table   rate  votes listed_in(type)
# 0          Yes         No  3.8/5    918          Buffet
# 1          Yes         No  4.0/5    324             NaN

# %%
df.shape
# Out:
# (4377, 12)

# %%
null=df.isna().sum()
null
# Out:
# name                              0
# listed_in(city)                 664
# rest_type                         0
# dish_liked                     1496
# cuisines                          0
# location                          0
# approx_cost(for two people)      45
# online_order                      0
# book_table                        0
# rate                            251
# votes                             0
# listed_in(type)                 664
# dtype: int64

# %%
import missingno as msno
msno.bar(df,color='maroon')

# %%
msno.heatmap(df)

# %%
null=df.isna().sum()
null
# Out:
# name                              0
# listed_in(city)                 664
# rest_type                         0
# dish_liked                     1496
# cuisines                          0
# location                          0
# approx_cost(for two people)      45
# online_order                      0
# book_table                        0
# rate                            251
# votes                             0
# listed_in(type)                 664
# dtype: int64

# %% [markdown]
# #Dealing with Null values
#
# Now We can see we Null values for total five columns , if we drop all the null values we will lost huge data from our dataframe.
#
# So to avoid data loss we are going to replace null values with some values assigned at each place of null locations.
#
# We can do it will below process:

# %%
location_groupby=df.groupby('listed_in(city)')
location_groupby.describe()
# Out:
#                        votes                                              \
#                        count        mean          std  min    25%    50%
# listed_in(city)
# BTM                    261.0  422.965517  1363.533908  0.0  22.00   85.0
# Banashankari            71.0  212.042254   239.507079  0.0  60.00  144.0
# Bannerghatta Road      105.0  109.285714   169.278941  0.0  13.00   46.0
# Basavanagudi           113.0  230.106195   288.817644  0.0  50.00  144.0
# Bellandur               58.0  146.034483   235.079603  0.0  23.00   38.0
# Brigade Road           158.0  200.044304   450.526152  0.0  10.00   50.0
# Brookefield             69.0  134.753623   235.760247  0.0  14.00   40.0
# Church Street          168.0  258.988095   566.138818  0.0  10.75   66.0
# Electronic City         45.0   49.911111    50.849521  0.0   4.00   43.0
# Frazer Town            106.0  251.509434   391.747349  0.0  20.00   66.0
# HSR                     99.0  169.909091   223.476068  0.0  36.00   74.0
# Indiranagar            173.0  287.098266   462.044492  0.0  17.00   97.0
# JP Nagar               143.0  178.881119   254.928835  0.0  14.00   61.0
# Jayanagar              200.0  231.945000   346.716184  0.0  27.25   91.0
# Kalyan Nagar           106.0  130.216981   201.306542  0.0  17.00   46.0
# Kammanahalli           103.0  110.514563   158.905932  0.0  16.50   46.0
# Koramangala 4th Block  241.0  490.360996  1217.674350  0.0  26.00  138.0
# Koramangala 5th Block  188.0  407.712766   684.214013  0.0  29.50  138.0
# Koramangala 6th Block  210.0  392.966667   769.642074  0.0  26.25   93.0
# Koramangala 7th Block  236.0  378.182203   631.113522  0.0  27.75  128.0
# Lavelle Road           150.0  221.800000   488.230210  0.0  11.00   56.0
# MG Road                135.0  215.874074   504.717720  0.0  10.50   61.0
# Malleshwaram            77.0  187.519481   225.361149  0.0  20.00   72.0
# Marathahalli            60.0  100.166667   176.630627  0.0  12.00   40.0
# New BEL Road            60.0  311.816667   554.225417  0.0  18.00  120.0
# Old Airport Road        91.0  267.329670   432.785655  0.0  11.50   71.0
# Rajajinagar             44.0  143.568182   174.136861  0.0   8.00   74.5
# Residency Road         125.0  158.776000   283.647068  0.0  10.00   46.0
# Sarjapur Road           65.0  110.953846   158.354767  0.0  19.00   37.0
# Whitefield              53.0  108.471698   211.520467  0.0  14.00   25.0
#
#
#                           75%      max
# listed_in(city)
# BTM                    400.00  14654.0
# Banashankari           234.00    918.0
# Bannerghatta Road      127.00    727.0
# Basavanagudi           240.00   1872.0
# Bellandur              128.75    894.0
# Brigade Road           161.50   3547.0
# Brookefield             72.00    819.0
# Church Street          256.25   3573.0
# Electronic City         79.00    159.0
# Frazer Town            362.00   1852.0
# HSR                    202.00    895.0
# Indiranagar            289.00   2654.0
# JP Nagar               204.00   1445.0
# Jayanagar              272.50   1919.0
# Kalyan Nagar           140.00   1181.0
# Kammanahalli           124.00    722.0
# Koramangala 4th Block  464.00  14704.0
# Koramangala 5th Block  431.00   3845.0
# Koramangala 6th Block  373.00   7127.0
# Koramangala 7th Block  414.00   3854.0
# Lavelle Road           162.75   3569.0
# MG Road                154.00   3596.0
# Malleshwaram           272.00    744.0
# Marathahalli            85.00    707.0
# New BEL Road           530.75   3912.0
# Old Airport Road       287.00   1920.0
# Rajajinagar            257.50    723.0
# Residency Road         123.00   1750.0
# Sarjapur Road          109.00    573.0
# Whitefield              57.00    843.0

# %% [markdown]
# We can see from above table data, we have 30 listed city locations from which Rajajinagar has smallest count , so we are replacing all null values with Rajajinagar in listed in city column as :

# %%
df['listed_in(city)'] = df['listed_in(city)'].fillna('Unknown')
null=df.isna().sum()
null
# Out:
# name                              0
# listed_in(city)                   0
# rest_type                         0
# dish_liked                     1496
# cuisines                          0
# location                          0
# approx_cost(for two people)      45
# online_order                      0
# book_table                        0
# rate                            251
# votes                             0
# listed_in(type)                 664
# dtype: int64

# %% [markdown]
# So we replaced all null values with "**Unknown**" in liste city column, Now we are going to replace null values from dish_liked by giving some dish names into null values:

# %%
df['dish_liked'] = df['dish_liked'].fillna('pizza_pasta_coffee')
null=df.isna().sum()
null
# Out:
# name                             0
# listed_in(city)                  0
# rest_type                        0
# dish_liked                       0
# cuisines                         0
# location                         0
# approx_cost(for two people)     45
# online_order                     0
# book_table                       0
# rate                           251
# votes                            0
# listed_in(type)                664
# dtype: int64

# %% [markdown]
# Now to replace null values from approx_cost(for two people) we need to check all existing cost values and we can calculate its median value so that we can replace with that value as:

# %%
df.head(2)
# Out:
#               name listed_in(city)            rest_type  \
# 0  San Churro Cafe    Banashankari  Cafe, Casual Dining
# 1   Penthouse Cafe         Unknown                 Cafe
#
#                                           dish_liked  \
# 0  Churros, Cannelloni, Minestrone Soup, Hot Choc...
# 1  Pizza, Mocktails, Coffee, Nachos, Salad, Pasta...
#
#                      cuisines      location approx_cost(for two people)  \
# 0      Cafe, Mexican, Italian  Banashankari                         800
# 1  Cafe, Italian, Continental  Banashankari                         700
#
#   online_order book_table   rate  votes listed_in(type)
# 0          Yes         No  3.8/5    918          Buffet
# 1          Yes         No  4.0/5    324             NaN

# %%
#mean_value=df['approx_cost(for two people)'].mean(skipna = True)
#mean=approx_cost(for two people).mean(axis = 1, skipna = True)
#df['approx_cost(for two people)'].mean(skipna = True)

# %%
df.rename(columns = {'approx_cost(for two people)':'Cost_Two_People'}, inplace = True)
df.head(2)
# Out:
#               name listed_in(city)            rest_type  \
# 0  San Churro Cafe    Banashankari  Cafe, Casual Dining
# 1   Penthouse Cafe         Unknown                 Cafe
#
#                                           dish_liked  \
# 0  Churros, Cannelloni, Minestrone Soup, Hot Choc...
# 1  Pizza, Mocktails, Coffee, Nachos, Salad, Pasta...
#
#                      cuisines      location Cost_Two_People online_order  \
# 0      Cafe, Mexican, Italian  Banashankari             800          Yes
# 1  Cafe, Italian, Continental  Banashankari             700          Yes
#
#   book_table   rate  votes listed_in(type)
# 0         No  3.8/5    918          Buffet
# 1         No  4.0/5    324             NaN

# %%
# We are getting error while replacing null values with median of cost of two people because the numbers having commas.
# So we need to remove commas first as:
df['Cost_Two_People'] = df['Cost_Two_People'].str.replace(',','')

# %%
#gfg['G2'].fillna(value=mean_value, inplace=True)
median_value=df['Cost_Two_People'].median()
df['Cost_Two_People'].fillna(value=median_value, inplace=True)

# %%
null=df.isna().sum()
null
# Out:
# name                 0
# listed_in(city)      0
# rest_type            0
# dish_liked           0
# cuisines             0
# location             0
# Cost_Two_People      0
# online_order         0
# book_table           0
# rate               251
# votes                0
# listed_in(type)    664
# dtype: int64

# %% [markdown]
# As can see we still have two columns which contacin null values those are rate and listed in (type).
# Now we are going to replace listed in type null values to "Cafes", as :

# %%
df['listed_in(type)'] = df['listed_in(type)'].fillna('Cafes')
null=df.isna().sum()
null
# Out:
# name                 0
# listed_in(city)      0
# rest_type            0
# dish_liked           0
# cuisines             0
# location             0
# Cost_Two_People      0
# online_order         0
# book_table           0
# rate               251
# votes                0
# listed_in(type)      0
# dtype: int64

# %% [markdown]
# As we know that rate column has rating out of 5 , so we need to remove /5 from all the rows so as to get single integer number, we can replace method as :

# %%
df['rate'] = df['rate'].str.replace('/5','')
df.head(3)
# Out:
#               name listed_in(city)            rest_type  \
# 0  San Churro Cafe    Banashankari  Cafe, Casual Dining
# 1   Penthouse Cafe         Unknown                 Cafe
# 2        Smacznego    Banashankari                 Cafe
#
#                                           dish_liked  \
# 0  Churros, Cannelloni, Minestrone Soup, Hot Choc...
# 1  Pizza, Mocktails, Coffee, Nachos, Salad, Pasta...
# 2  Waffles, Pasta, Coleslaw Sandwich, Choco Waffl...
#
#                                    cuisines      location Cost_Two_People  \
# 0                    Cafe, Mexican, Italian  Banashankari             800
# 1                Cafe, Italian, Continental  Banashankari             700
# 2  Cafe, Mexican, Italian, Momos, Beverages  Banashankari             550
#
#   online_order book_table rate  votes listed_in(type)
# 0          Yes         No  3.8    918          Buffet
# 1          Yes         No  4.0    324           Cafes
# 2          Yes         No  4.2    504           Cafes

# %%
df.rename(columns = {'rate':'Rate(Out of 5)'}, inplace = True)
df.head(2)
# Out:
#               name listed_in(city)            rest_type  \
# 0  San Churro Cafe    Banashankari  Cafe, Casual Dining
# 1   Penthouse Cafe         Unknown                 Cafe
#
#                                           dish_liked  \
# 0  Churros, Cannelloni, Minestrone Soup, Hot Choc...
# 1  Pizza, Mocktails, Coffee, Nachos, Salad, Pasta...
#
#                      cuisines      location Cost_Two_People online_order  \
# 0      Cafe, Mexican, Italian  Banashankari             800          Yes
# 1  Cafe, Italian, Continental  Banashankari             700          Yes
#
#   book_table Rate(Out of 5)  votes listed_in(type)
# 0         No            3.8    918          Buffet
# 1         No            4.0    324           Cafes

# %% [markdown]
# To replace all null values to median from rate column , we are seeing some values rows with "NEW" string , so first we need to remove these values, as :

# %%
#median_value=df['Rate(Out of 5)'].median()
#df['Rate(Out of 5)'].fillna(value=median_value, inplace=True)

# %%
df['Rate(Out of 5)'] = df['Rate(Out of 5)'].str.replace('NEW','')
df.head(2)
# Out:
#               name listed_in(city)            rest_type  \
# 0  San Churro Cafe    Banashankari  Cafe, Casual Dining
# 1   Penthouse Cafe         Unknown                 Cafe
#
#                                           dish_liked  \
# 0  Churros, Cannelloni, Minestrone Soup, Hot Choc...
# 1  Pizza, Mocktails, Coffee, Nachos, Salad, Pasta...
#
#                      cuisines      location Cost_Two_People online_order  \
# 0      Cafe, Mexican, Italian  Banashankari             800          Yes
# 1  Cafe, Italian, Continental  Banashankari             700          Yes
#
#   book_table Rate(Out of 5)  votes listed_in(type)
# 0         No            3.8    918          Buffet
# 1         No            4.0    324           Cafes

# %%
df['Rate(Out of 5)'] = df['Rate(Out of 5)'].str.replace('-','')
df.head(2)
# Out:
#               name listed_in(city)            rest_type  \
# 0  San Churro Cafe    Banashankari  Cafe, Casual Dining
# 1   Penthouse Cafe         Unknown                 Cafe
#
#                                           dish_liked  \
# 0  Churros, Cannelloni, Minestrone Soup, Hot Choc...
# 1  Pizza, Mocktails, Coffee, Nachos, Salad, Pasta...
#
#                      cuisines      location Cost_Two_People online_order  \
# 0      Cafe, Mexican, Italian  Banashankari             800          Yes
# 1  Cafe, Italian, Continental  Banashankari             700          Yes
#
#   book_table Rate(Out of 5)  votes listed_in(type)
# 0         No            3.8    918          Buffet
# 1         No            4.0    324           Cafes

# %%
#median_value=df['Rate(Out of 5)'].median()
#df['Rate(Out of 5)'].fillna(value=median_value, inplace=True)

df['Rate(Out of 5)'] = df['Rate(Out of 5)'].astype(int)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-98-d70743f58c44> in <module>()
#       2 #df['Rate(Out of 5)'].fillna(value=median_value, inplace=True)
#       3
# ----> 4 df['Rate(Out of 5)'] = df['Rate(Out of 5)'].astype(int)
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/generic.py in astype(self, dtype, copy, errors)
#    5813         else:
#    5814             # else, only a single dtype is given
# -> 5815             new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#    5816             return self._constructor(new_data).__finalize__(self, method="astype")
#    5817
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/internals/managers.py in astype(self, dtype, copy, errors)
#     416
#     417     def astype(self: T, dtype, copy: bool = False, errors: str = "raise") -> T:
# --> 418         return self.apply("astype", dtype=dtype, copy=copy, errors=errors)
#     419
#     420     def convert(
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/internals/managers.py in apply(self, f, align_keys, ignore_failures, **kwargs)
#     325                     applied = b.apply(f, **kwargs)
#     326                 else:
# --> 327                     applied = getattr(b, f)(**kwargs)
#     328             except (TypeError, NotImplementedError):
#     329                 if not ignore_failures:
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/internals/blocks.py in astype(self, dtype, copy, errors)
#     589         values = self.values
#     590
# --> 591         new_values = astype_array_safe(values, dtype, copy=copy, errors=errors)
#     592
#     593         new_values = maybe_coerce_values(new_values)
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/dtypes/cast.py in astype_array_safe(values, dtype, copy, errors)
#    1307
#    1308     try:
# -> 1309         new_values = astype_array(values, dtype, copy=copy)
#    1310     except (ValueError, TypeError):
#    1311         # e.g. astype_nansafe can fail on object-dtype of strings
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/dtypes/cast.py in astype_array(values, dtype, copy)
#    1255
#    1256     else:
# -> 1257         values = astype_nansafe(values, dtype, copy=copy)
#    1258
#    1259     # in pandas we don't store numpy str dtypes, so convert to object
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/dtypes/cast.py in astype_nansafe(arr, dtype, copy, skipna)
#    1172         # work around NumPy brokenness, #1987
#    1173         if np.issubdtype(dtype.type, np.integer):
# -> 1174             return lib.astype_intsafe(arr, dtype)
#    1175
#    1176         # if we have a datetime/timedelta array of objects
#
# /usr/local/lib/python3.7/dist-packages/pandas/_libs/lib.pyx in pandas._libs.lib.astype_intsafe()
#
# ValueError: invalid literal for int() with base 10: '3.8'
