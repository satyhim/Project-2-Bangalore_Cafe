# %% [markdown]
# <a href="https://colab.research.google.com/github/satyhim/Project-2-Bangalore_Cafe/blob/main/Rough_Book1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv('/content/drive/MyDrive/Python/Project/Bangalore_Cafe_Zomato.csv')
df.head()
# Out:
#                                                 name online_order book_table  \
# 0                                    San Churro Cafe          Yes         No
# 1                                     Penthouse Cafe          Yes         No
# 2                                          Smacznego          Yes         No
# 3  CafÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂ© Down The A...          Yes         No
# 4                                       Cafe Shuffle          Yes        Yes
#
#     rate  votes      location            rest_type  \
# 0  3.8/5    918  Banashankari  Cafe, Casual Dining
# 1  4.0/5    324  Banashankari                 Cafe
# 2  4.2/5    504  Banashankari                 Cafe
# 3  4.1/5    402  Banashankari                 Cafe
# 4  4.2/5    150  Banashankari                 Cafe
#
#                                           dish_liked  \
# 0  Churros, Cannelloni, Minestrone Soup, Hot Choc...
# 1  Pizza, Mocktails, Coffee, Nachos, Salad, Pasta...
# ...

# %%
df.rename(columns = {'listed_in(city)':'Area_Name'}, inplace = True)
df.head(20)
# Out:
#                                                  name online_order book_table  \
# 0                                     San Churro Cafe          Yes         No
# 1                                      Penthouse Cafe          Yes         No
# 2                                           Smacznego          Yes         No
# 3   CafÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂ© Down The A...          Yes         No
# 4                                        Cafe Shuffle          Yes        Yes
# 5                                    The Coffee Shack          Yes        Yes
# 6                                          Caf-Eleven           No         No
# 7                                     San Churro Cafe          Yes         No
# 8                                       Cafe Vivacity          Yes         No
# 9                                        Catch-up-ino          Yes         No
# 10                                   Kirthi's Biryani          Yes         No
# ...

# %%
df.loc[df['name'].str.contains('Ã', case=False), 'name_1'] = 'Ã'
df
# Out:
#                                                    name online_order  \
# 0                                       San Churro Cafe          Yes
# 1                                        Penthouse Cafe          Yes
# 2                                             Smacznego          Yes
# 3     CafÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂ© Down The A...          Yes
# 4                                          Cafe Shuffle          Yes
# ...                                                 ...          ...
# 4372                                           Tata Cha          Yes
# 4373                                            Teashot           No
# 4374                         The Coffee Bean & Tea Leaf          Yes
# 4375                                         Cafe Thulp          Yes
# 4376      Re:fuel- Aloft Bengaluru Cessna Business Park           No
#
#      book_table    rate  votes                    location  \
# 0            No   3.8/5    918                Banashankari
# ...

# %%
df['name_1'].value_counts(dropna=False)
# Out:
# NaN    4253
# Ã      124
# Name: name_1, dtype: int64

# %%
df
# Out:
#                                                    name online_order  \
# 0                                       San Churro Cafe          Yes
# 1                                        Penthouse Cafe          Yes
# 2                                             Smacznego          Yes
# 3     CafÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂ© Down The A...          Yes
# 4                                          Cafe Shuffle          Yes
# ...                                                 ...          ...
# 4372                                           Tata Cha          Yes
# 4373                                            Teashot           No
# 4374                         The Coffee Bean & Tea Leaf          Yes
# 4375                                         Cafe Thulp          Yes
# 4376      Re:fuel- Aloft Bengaluru Cessna Business Park           No
#
#      book_table    rate  votes                    location  \
# 0            No   3.8/5    918                Banashankari
# ...
